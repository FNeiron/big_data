# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
import findspark

findspark.init()

from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark.sql as sql
from pyspark.sql.types import DoubleType, IntegerType, ArrayType, StringType
from pyspark.sql.functions import udf, col, max, sum, countDistinct, explode, size
from math import sin, cos, sqrt, atan2, radians
import re

spark = SparkSession.builder.master("local[*]").config("spark.jars.packages", "com.databricks:spark-xml_2.12:0.13.0").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://dd9ab0bb3dcf:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
pl_df = spark.read.csv('programming-languages.csv', header=True, inferSchema=True, sep=",")
pl_df.show(5)
pl_df.printSchema()

langs = [str(t['name']).lower() for t in pl_df.select('name').collect()]
print(langs)
# Out:
# +----------+--------------------+
# |      name|       wikipedia_url|
# +----------+--------------------+
# |   A# .NET|https://en.wikipe...|
# |A# (Axiom)|https://en.wikipe...|
# |A-0 System|https://en.wikipe...|
# |        A+|https://en.wikipe...|
# |       A++|https://en.wikipe...|
# +----------+--------------------+
# only showing top 5 rows
#
# root
#  |-- name: string (nullable = true)
#  |-- wikipedia_url: string (nullable = true)
#
# ['a# .net', 'a# (axiom)', 'a-0 system', 'a+', 'a++', 'abap', 'abc', 'abc algol', 'abset', 'absys', 'acc', 'accent', 'ace dasl', 'acl2', 'act-iii', 'action!', 'actionscript', 'ada', 'adenine', 'agda', 'agilent vee', 'agora', 'aimms', 'alef', 'alf', 'algol 58', 'algol 60', 'algol 68', 'algol w', 'alice', 'alma-0', 'ambienttalk', 'amiga e', 'amos', 'ampl', 'apex (salesforce.com)', 'apl', "app inventor for android's visual block language", 'applescript', 'arc', 'arexx', 'argus', 'aspectj', 'assembly language', 'ats', 'ateji px', 'autohotkey', 'autocoder', 'autoit', 'autolisp / visual lisp', 'averest', 'awk', 'axum', 'b', 'babbage', 'bash', 'basic', 'bc', 'bcpl', 'beanshell', 'batch (windows/dos)', 'bertrand', 'beta', 'bigwig', 'bistro', 'bitc', 'bliss', 'blockly', 'bloop', 'blue', 'boo', 'boomerang', 'bourne shell (including', 'bash and', 'ksh )', 'brew', 'bpel', 'c', 'c--', 'c++ – iso/iec 14882', 'c# – iso/iec 23270', 'c/al', 'caché objectscript', 'c shell', 'caml', 'cayenne', 'cduce', 'cecil', 'cel', 'cesil', 'ceylon', 'cfengine', 'cfml', 'cg', 'ch', 'chapel', 'chain', 'charity', 'charm', 'chef', 'chill', 'chip-8', 'chomski', 'chuck', 'cics', 'cilk', 'citrine (programming language)', 'cl (ibm)', 'claire', 'clarion', 'clean', 'clipper', 'clist', 'clojure', 'clu', 'cms-2', 'cobol – iso/iec 1989', 'cobra', 'code', 'coffeescript', 'coldfusion', 'comal', 'combined programming language (cpl)', 'comit', 'common intermediate language (cil)', 'common lisp (also known as cl)', 'compass', 'component pascal', 'constraint handling rules (chr)', 'converge', 'cool', 'coq', 'coral 66', 'corn', 'corvision', 'cowsel', 'cpl', 'cryptol', 'csh', 'csound', 'csp', 'cuda', 'curl', 'curry', 'cyclone', 'cython', 'd', "dasl (datapoint's advanced systems language)", 'dasl (distributed application specification language)', 'dart', 'dataflex', 'datalog', 'datatrieve', 'dbase', 'dc', 'dcl', 'deesel (formerly g)', 'delphi', 'dinkc', 'dibol', 'dog', 'draco', 'drakon', 'dylan', 'dynamo', 'e', 'e#', 'ease', 'easy pl/i', 'easy programming language', 'easytrieve plus', 'ecmascript', 'edinburgh imp', 'egl', 'eiffel', 'elan', 'elixir', 'elm', 'emacs lisp', 'emerald', 'epigram', 'epl', 'erlang', 'es', 'escher', 'espol', 'esterel', 'etoys', 'euclid', 'euler', 'euphoria', 'euslisp robot programming language', 'cms exec (exec)', 'exec 2', 'executable uml', 'f', 'f#', 'factor', 'falcon', 'fantom', 'faust', 'ffp', 'fjölnir', 'fl', 'flavors', 'flex', 'floop', 'flow-matic', 'focal', 'focus', 'foil', 'formac', '@formula', 'forth', 'fortran – iso/iec 1539', 'fortress', 'foxbase', 'foxpro', 'fp', 'fpr', 'franz lisp', 'frege', 'f-script', 'g', 'game maker language', 'gamemonkey script', 'gams', 'gap', 'g-code', 'genie', 'gdl', 'gj', 'george', 'glsl', 'gnu e', 'gm', 'go', 'go!', 'goal', 'gödel', 'godiva', 'golo', 'gom (good old mad)', 'google apps script', 'gosu', 'gotran', 'gpss', 'graphtalk', 'grass', 'groovy', 'hack', 'hal/s', 'hamilton c shell', 'harbour', 'hartmann pipelines', 'haskell', 'haxe', 'high level assembly', 'hlsl', 'hop', 'hopscotch', 'hope', 'hugo', 'hume', 'hypertalk', 'ibm basic assembly language', 'ibm hascript', 'ibm informix-4gl', 'ibm rpg', 'ici', 'icon', 'id', 'idl', 'idris', 'imp', 'inform', 'io', 'ioke', 'ipl', 'iptscrae', 'islisp', 'ispf', 'iswim', 'j', 'j#', 'j++', 'jade', 'jako', 'jal', 'janus (concurrent constraint programming language)', 'janus (time-reversible computing programming language)', 'jass', 'java', 'javascript', 'jcl', 'jean', 'join java', 'joss', 'joule', 'jovial', 'joy', 'jscript', 'jscript .net', 'javafx script', 'julia', 'jython', 'k', 'kaleidoscope', 'karel', 'karel++', 'kee', 'kixtart', 'klerer-may system', 'kif', 'kojo', 'kotlin', 'krc', 'krl', 'kuka robot language)', 'krypton', 'ksh', 'l', 'l# .net', 'labview', 'ladder', 'lagoona', 'lansa', 'lasso', 'latex', 'lava', 'lc-3', 'leda', 'legoscript', 'lil', 'lilypond', 'limbo', 'limnor', 'linc', 'lingo', 'lis', 'lisa', 'lisaac', 'lisp – iso/iec 13816', 'lite-c', 'lithe', 'little b', ' ...

# %%
posts_df = spark.read.format('xml').options(rowTag="row").load('posts_sample.xml')
posts_df.show(5)
posts_df.printSchema()
# Out:
# +-----------------+------------+--------------------+-----------+-------------+--------------------+--------------------+--------------+---+--------------------+--------------------+----------------------+-----------------+-----------------+------------+---------+-----------+------+--------------------+--------------------+----------+
# |_AcceptedAnswerId|_AnswerCount|               _Body|_ClosedDate|_CommentCount| _CommunityOwnedDate|       _CreationDate|_FavoriteCount|_Id|   _LastActivityDate|       _LastEditDate|_LastEditorDisplayName|_LastEditorUserId|_OwnerDisplayName|_OwnerUserId|_ParentId|_PostTypeId|_Score|               _Tags|              _Title|_ViewCount|
# +-----------------+------------+--------------------+-----------+-------------+--------------------+--------------------+--------------+---+--------------------+--------------------+----------------------+-----------------+-----------------+------------+---------+-----------+------+--------------------+--------------------+----------+
# |                7|          13|<p>I want to use ...|       null|            2|2012-10-31 16:42:...|2008-07-31 21:42:...|            48|  4|2019-07-19 01:39:...|2019-07-19 01:39:...|                Rich B|          3641067|             null|           8|     null|          1|   630|<c#><floating-poi...|Convert Decimal t...|     42817|
# |               31|           6|<p>I have an abso...|       null|            0|                null|2008-07-31 22:08:...|            10|  6|2019-07-19 01:43:...|2019-07-19 01:43:...|                Rich B|          3641067|             null|           9|     null|          1|   281|<html><css><inter...|Percentage width ...|     18214|
# |             null|        null|<p>An explicit ca...|       null|            0|                null|2008-07-31 22:17:...|          null|  7|2017-12-16 05:06:...|2017-12-16 05:06:...|                  null|          4020527|             null|           9|        4|          2|   425|                null|                null|      null|
# |             1404|          63|<p>Given a <code>...|       null|            5|2011-08-16 19:40:...|2008-07-31 23:40:...|           436|  9|2019-06-26 15:25:...|2018-04-21 17:48:...|                Rich B|          3956566|             null|           1|     null|          1|  1742|<c#><.net><datetime>|How do I calculat...|    555183|
# |             1248|          37|<p>Given a specif...|       null|            3|2009-09-04 13:15:...|2008-07-31 23:55:...|           539| 11|2019-05-26 02:31:...|2017-06-04 15:51:...|           user2370523|          6479704|             null|           1|     null|          1|  1444|<c#><datetime><ti...|Calculate relativ...|    149445|
# +-----------------+------------+--------------------+-----------+-------------+--------------------+--------------------+--------------+---+--------------------+--------------------+----------------------+-----------------+-----------------+------------+---------+-----------+------+--------------------+--------------------+----------+
# only showing top 5 rows
#
# root
#  |-- _AcceptedAnswerId: long (nullable = true)
#  |-- _AnswerCount: long (nullable = true)
#  |-- _Body: string (nullable = true)
#  |-- _ClosedDate: timestamp (nullable = true)
#  |-- _CommentCount: long (nullable = true)
#  |-- _CommunityOwnedDate: timestamp (nullable = true)
#  |-- _CreationDate: timestamp (nullable = true)
#  |-- _FavoriteCount: long (nullable = true)
#  |-- _Id: long (nullable = true)
#  |-- _LastActivityDate: timestamp (nullable = true)
#  |-- _LastEditDate: timestamp (nullable = true)
#  |-- _LastEditorDisplayName: string (nullable = true)
#  |-- _LastEditorUserId: long (nullable = true)
#  |-- _OwnerDisplayName: string (nullable = true)
#  |-- _OwnerUserId: long (nullable = true)
#  |-- _ParentId: long (nullable = true)
#  |-- _PostTypeId: long (nullable = true)
#  |-- _Score: long (nullable = true)
#  |-- _Tags: string (nullable = true)
#  |-- _Title: string (nullable = true)
#  |-- _ViewCount: long (nullable = true)

# %% [markdown]
# # Задание
# Сформировать отчёт с информацией о 10 наиболее популярных языках программирования по итогам года за период с 2010 по 2020 годы. Отчёт будет отражать динамику изменения популярности языков программирования и представлять собой набор таблиц "топ-10" для каждого года.
#
# Получившийся отчёт сохранить в формате Apache Parquet.
#
# Для выполнения задания вы можете использовать любую комбинацию Spark API: RDD API, Dataset API, SQL API.

# %%
def get_tags(tags_string):
    if not tags_string:
        return []
    pattern = r'<([^>]+)>'
    tags = re.findall(pattern, tags_string)
    res = []
    for tag in tags:
        if tag.lower() in langs:
            res.append(tag.lower())
    return res

def get_year(date_and_time):
    return date_and_time.year

get_tags_udf = udf(get_tags, ArrayType(StringType()))
get_year_udf = udf(get_year, IntegerType())

posts_data_simplified = posts_df \
    .withColumn("tags", get_tags_udf(posts_df["_Tags"])) \
    .withColumn("year", get_year_udf(posts_df["_LastActivityDate"])) \
    .select("tags", "year", col("_ViewCount").alias("views")) \
    .filter(size("tags") > 0)

first_rows = posts_data_simplified.collect()

for i, row in enumerate(first_rows):
    print(i + 1, row)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2819 Row(tags=['java', 'awk'], year=2013, views=1430)
# 2820 Row(tags=['r'], year=2013, views=149)
# 2821 Row(tags=['javascript', 'php'], year=2013, views=258)
# 2822 Row(tags=['powershell'], year=2013, views=1483)
# 2823 Row(tags=['java'], year=2013, views=554)
# 2824 Row(tags=['objective-c'], year=2014, views=19)
# 2825 Row(tags=['bash', 'perl'], year=2014, views=101)
# 2826 Row(tags=['php'], year=2014, views=38)
# 2827 Row(tags=['java'], year=2016, views=6562)
# 2828 Row(tags=['java'], year=2018, views=1857)
# 2829 Row(tags=['javascript'], year=2014, views=63)
# 2830 Row(tags=['php'], year=2017, views=34)
# 2831 Row(tags=['java'], year=2014, views=886)
# 2832 Row(tags=['php'], year=2015, views=48)
# 2833 Row(tags=['python'], year=2019, views=3633)
# 2834 Row(tags=['r'], year=2014, views=550)
# 2835 Row(tags=['php'], year=2014, views=678)
# 2836 Row(tags=['java'], year=2015, views=2265)
# 2837 Row(tags=['php'], year=2014, views=93)
# 2838 Row(tags=['java'], year=2014, views=1109)
# 2839 Row(tags=['python', 'cuda'], year=2014, views=392)
# 2840 Row(tags=['c'], year=2014, views=11950)
# 2841 Row(tags=['java'], year=2016, views=264)
# 2842 Row(tags=['javascript'], year=2014, views=340)
# 2843 Row(tags=['scala'], year=2014, views=1939)
# 2844 Row(tags=['javascript'], year=2014, views=52)
# 2845 Row(tags=['javascript'], year=2014, views=142)
# 2846 Row(tags=['javascript'], year=2014, views=182)
# 2847 Row(tags=['matlab'], year=2015, views=534)
# 2848 Row(tags=['python'], year=2014, views=422)
# 2849 Row(tags=['python'], year=2014, views=423)
# 2850 Row(tags=['php'], year=2014, views=368)
# 2851 Row(tags=['javascript'], year=2014, views=853)
# 2852 Row(tags=['javascript'], year=2014, views=24)
# 2853 Row(tags=['perl'], year=2014, views=136)
# 2854 Row(tags=['r'], year=2017, views=2527)
# 2855 Row(tags=['javascript'], year=2016, views=29)
# 2856 Row(tags=['java'], year=2016, views=656)
# 2857 Row(tags=['ruby'], year=2016, views=396)
# 2858 Row(tags=['javascript'], year=2016, views=53)
# 2859 Row(tags=['c'], year=2017, views=315)
# 2860 Row(tags=['javascript'], year=2016, views=83)
# 2861 Row(tags=['ruby'], year=2018, views=812)
# 2862 Row(tags=['typescript'], year=2016, views=1276)
# 2863 Row(tags=['php'], year=2016, views=27)
# 2864 Row(tags=['java'], year=2016, views=403)
# 2865 Row(tags=['scala'], year=2016, views=293)
# 2866 Row(tags=['javascript', 'php'], year=2016, views=48)
# 2867 Row(tags=['java'], year=2016, views=991)
# 2868 Row(tags=['php', 'xpath'], year=2016, views=39)
# 2869 Row(tags=['autohotkey'], year=2016, views=92)
# 2870 Row(tags=['java'], year=2016, views=512)
# 2871 Row(tags=['r'], year=2016, views=40)
# 2872 Row(tags=['java'], year=2016, views=67)
# 2873 Row(tags=['python'], year=2016, views=7035)
# 2874 Row(tags=['java'], year=2016, views=642)
# 2875 Row(tags=['c'], year=2016, views=2694)
# 2876 Row(tags=['java'], year=2016, views=35)
# 2877 Row(tags=['javascript', 'php'], year=2016, views=464)
# 2878 Row(tags=['python'], year=2016, views=3055)
# 2879 Row(tags=['javascript'], year=2016, views=115)
# 2880 Row(tags=['java'], year=2016, views=554)
# 2881 Row(tags=['r'], year=2016, views=56)
# 2882 Row(tags=['php'], year=2016, views=132)
# 2883 Row(tags=['javascript'], year=2016, views=822)
# 2884 Row(tags=['javascript'], year=2016, views=72)
# 2885 Row(tags=['javascript'], year=2016, views=1851)
# 2886 Row(tags=['java'], year=2016, views=219)
# 2887 Row(tags=['ruby'], year=2016, views=293)
# 2888 Row(tags=['javascript'], year=2016, views=52)
# 2889 Row(tags=['php'], year=2019, views=35)
# 2890 Row(tags=['java'], year=2017, views=308)
# 2891 Row(tags=['java'], year=2017, views=446)
# 2892 Row(tags=['python'], year=2017, views=80)
# 2893 Row(tags=['python', 'xpath'], year=2017, views=139)
# 2894 Row(tags=['java'], year=2017, views=1371)
# 2895 Row(tags=['python'], year=2017, views=310)
# 2896 Row(tags=['javascript'], year=2017, views=443)
# 2897 Row(tags=['php'], year=2017, views=394)
# 2898 Row(tags=['php'], year=2017, views=82)
# 2899 Row(tags=['python'], year=2017, views=3322)
# 2900 Row(tags=['matlab'], year=2017, views=78)
# 2901 Row(tags=['python'], year=2017, views=48)
# 2902 Row(tags=['javascript'], year=2017, views=275)
# 2903 Row(tags=['javascript'], year=2017, views=337)
# 2904 Row(tags=['python'], year=2017, views=230)
# 2905 Row(tags=['xpath'], year=2017, views=84)
# 2906 Row(tags=['ruby'], year=2017, views=41)
# 2907 Row(tags=['scala'], year=2017, views=136)
# 2908 Row(tags=['javascript'], year=2017, views=127)
# 2909 Row(tags=['java'], year=2017, views=110)
# 2910 Row(tags=['typescript'], year=2017, views=3357)
# 2911 Row(tags=['c', 'ada'], year=2017, views=67)
# 2912 Row(tags=['php'], year=2017, views=610)
# 2913 Row(tags=['r'], year=2017, views=127)
# 2914 Row(tags=['python'], year=2017, views=520)
# 2915 Row(tags=['objective-c'], year=2017, views=102)
# 2916 Row(tags=['javascript'], year=2017, views=306)
# 2917 Row(tags=['awk'], year=2017, views=204)
# 2918 Row(tags=['php'], year=2017, views=33)
# 2919 Row(tags=['java'], year=2017, views=212)
# 2920 Row(tags=['javascript'], year=2017, views=1297)
# 2921 Row(tags=['java'], year=2018, views=1173)
# 2922 Row(tags=['java'], year=2017, views=614)
# 2923 Row(tags=['c'], year=2018, views=319)
# 2924 Row(tags=['python'], year=2018, views=403)
# 2925 Row(tags=['javascript'], year=2018, views=1444)
# 2926 Row(tags=['java'], year=2018, views=193)
# 2927 Row(tags=['powershell'], year=2018, views=225)
# 2928 Row(tags=['php'], year=2018, views=40)
# 2929 Row(tags=['php'], year=2018, views=56)
# 2930 Row(tags=['scala'], year=2018, views=57)
# 2931 Row(tags=['python'], year=2018, views=1428)
# 2932 Row(tags=['python'], year=2018, views=152)
# 2933 Row(tags=['python'], year=2018, views=33)
# 2934 Row(tags=['java'], year=2018, views=208)
# 2935 Row(tags=['php'], year=2018, views=35)
# 2936 Row(tags=['elm'], year=2018, views=107)
# 2937 Row(tags=['java'], year=2018, views=1466)
# 2938 Row(tags=['python'], year=2018, views=75)
# 2939 Row(tags=['c'], year=2018, views=45)
# 2940 Row(tags=['java'], year=2018, views=492)
# 2941 Row(tags=['php'], year=2018, views=51)
# 2942 Row(tags=['php'], year=2018, views=31)
# 2943 Row(tags=['java'], year=2018, views=58)
# 2944 Row(tags=['python'], year=2018, views=69)
# 2945 Row(tags=['java'], year=2018, views=90)
# 2946 Row(tags=['python'], year=2018, views=260)
# 2947 Row(tags=['javascript'], year=2017, views=993)
# 2948 Row(tags=['bash'], year=2017, views=65)
# 2949 Row(tags=['php'], year=2017, views=55)
# 2950 Row(tags=['javascript'], year=2017, views=52)
# 2951 Row(tags=['java'], year=2017, views=130)
# 2952 Row(tags=['python'], year=2017, views=486)
# 2953 Row(tags=['r'], year=2017, views=58)
# 2954 Row(tags=['php'], year=2017, views=27)
# 2955 Row(tags=['autohotkey'], year=2017, views=34)
# 2956 Row(tags=['powershell'], year=2017, views=323)
# 2957 Row(tags=['php'], year=2017, views=168)
# 2958 Row(tags=['php'], year=2017, views=47)
# 2959 Row(tags=['java'], year=2017, views=464)
# 2960 Row(tags=['java'], year=2017, views=142)
# 2961 Row(tags=['python'], year=2017, views=98)
# 2962 Row(tags=['xpath'], year=2017, views=378)
# 2963 Row(tags=['javascript'], year=2017, views=39)
# 2964 Row(tags=['python'], year=2017, views=396)
# 2965 Row(tags=['c'], year=2017, views=1235)
# 2966 Row(tags=['python'], year=2017, views=1499)
# 2967 Row(tags=['java'], year=2017, views=947)
# 2968 Row(tags=['r'], year=2017, views=394)
# 2969 Row(tags=['r'], year=2017, views=374)
# 2970 Row(tags=['ruby'], year=2017, views=33)
# 2971 Row(tags=['php'], year=2017, views=3722)
# 2972 Row(tags=['python'], year=2018, views=132)
# 2973 Row(tags=['r'], year=2017, views=104)
# 2974 Row(tags=['javascript'], year=2017, views=165)
# 2975 Row(tags=['python'], year=2019, views=6753)
# 2976 Row(tags=['javascript'], year=2017, views=100)
# 2977 Row(tags=['php'], year=2017, views=731)
# 2978 Row(tags=['javascript'], year=2017, views=790)
# 2979 Row(tags=['javascript'], year=2017, views=49)
# 2980 Row(tags=['haskell'], year=2017, views=1384)
# 2981 Row(tags=['php', 'curl'], year=2018, views=56)
# 2982 Row(tags=['python'], year=2018, views=72)
# 2983 Row(tags=['python'], year=2018, views=44)
# 2984 Row(tags=['r'], year=2018, views=148)
# 2985 Row(tags=['javascript'], year=2018, views=38)
# 2986 Row(tags=['javascript'], year=2018, views=57)
# 2987 Row(tags=['java'], year=2018, views=34)
# 2988 Row(tags=['python'], year=2018, views=62)
# 2989 Row(tags=['python'], year=2018, views=26)
# 2990 Row(tags=['python'], year=2018, views=46)
# 2991 Row(tags=['c'], year=2018, views=48)
# 2992 Row(tags=['php'], year=2018, views=202)
# 2993 Row(tags=['java', 'python'], year=2018, views=65)
# 2994 Row(tags=['java'], year=2018, views=92)
# 2995 Row(tags=['python'], year=2018, views=24)
# 2996 Row(tags=['javascript', 'typescript'], year=2018, views=218)
# 2997 Row(tags=['python'], year=2018, views=61)
# 2998 Row(tags=['javascript'], year=2018, views=27)
# 2999 Row(tags=['php'], year=2018, views=213)
# 3000 Row(tags=['python'], year=2019, views=739)
# 3001 Row(tags=['python'], year=2018, views=40)
# 3002 Row(tags=['java'], year=2018, views=80)
# 3003 Row(tags=['php'], year=2018, views=34)
# 3004 Row(tags=['javascript'], year=2016, views=276)
# 3005 Row(tags=['powershell'], year=2015, views=6946)
# 3006 Row(tags=['python'], year=2015, views=221)
# 3007 Row(tags=['javascript'], year=2015, views=89)
# 3008 Row(tags=['java'], year=2015, views=138)
# 3009 Row(tags=['python'], year=2015, views=1372)
# 3010 Row(tags=['java'], year=2015, views=106)
# 3011 Row(tags=['python'], year=2015, views=68)
# 3012 Row(tags=['java'], year=2015, views=139)
# 3013 Row(tags=['c'], year=2015, views=73)
# 3014 Row(tags=['javascript'], year=2015, views=112)
# 3015 Row(tags=['python'], year=2015, views=279)
# 3016 Row(tags=['javascript'], year=2016, views=1163)
# 3017 Row(tags=['matlab'], year=2015, views=33)
# 3018 Row(tags=['python'], year=2016, views=84)
# 3019 Row(tags=['objective-c'], year=2015, views=34)
# 3020 Row(tags=['java'], year=2015, views=323)
# 3021 Row(tags=['java'], year=2015, views=621)
# 3022 Row(tags=['javascript'], year=2018, views=837)
# 3023 Row(tags=['php'], year=2015, views=68)
# 3024 Row(tags=['php'], year=2015, views=835)
# 3025 Row(tags=['javascript'], year=2015, views=122)
# 3026 Row(tags=['python'], year=2015, views=45)
# 3027 Row(tags=['ruby'], year=2015, views=206)
# 3028 Row(tags=['php'], year=2015, views=700)
# 3029 Row(tags=['c'], year=2015, views=1660)
# 3030 Row(tags=['python'], year=2019, views=22)
# 3031 Row(tags=['python'], year=2019, views=39)
# 3032 Row(tags=['prolog'], year=2019, views=28)
# 3033 Row(tags=['java'], year=2019, views=115)
# 3034 Row(tags=['javascript', 'java'], year=2019, views=25)
# 3035 Row(tags=['python', 'bash'], year=2019, views=36)
# 3036 Row(tags=['r'], year=2019, views=23)
# 3037 Row(tags=['javascript'], year=2019, views=132)
# 3038 Row(tags=['ocaml'], year=2019, views=23)
# 3039 Row(tags=['r'], year=2019, views=31)
# 3040 Row(tags=['java'], year=2019, views=44)
# 3041 Row(tags=['php'], year=2019, views=18)
# 3042 Row(tags=['matlab'], year=2019, views=23)
# 3043 Row(tags=['javascript'], year=2019, views=24)
# 3044 Row(tags=['php'], year=2019, views=60)
# 3045 Row(tags=['typescript'], year=2019, views=351)
# 3046 Row(tags=['javascript', 'curl'], year=2019, views=100)
# 3047 Row(tags=['javascript'], year=2019, views=54)
# 3048 Row(tags=['javascript'], year=2019, views=31)
# 3049 Row(tags=['scala'], year=2019, views=60)
# 3050 Row(tags=['python'], year=2019, views=38)
# 3051 Row(tags=['python'], year=2019, views=36)
# 3052 Row(tags=['java'], year=2019, views=45)
# 3053 Row(tags=['haskell'], year=2019, views=85)
# 3054 Row(tags=['python'], year=2019, views=274)
# 3055 Row(tags=['python'], year=2019, views=2194)
# 3056 Row(tags=['python'], year=2019, views=33)
# 3057 Row(tags=['python'], year=2019, views=43)
# 3058 Row(tags=['java'], year=2019, views=35)
# 3059 Row(tags=['java'], year=2016, views=39)
# 3060 Row(tags=['groovy'], year=2016, views=178)
# 3061 Row(tags=['javascript'], year=2017, views=177)
# 3062 Row(tags=['javascript'], year=2016, views=103)
# 3063 Row(tags=['haskell'], year=2016, views=87)
# 3064 Row(tags=['python'], year=2016, views=71)
# 3065 Row(tags=['javascript'], year=2016, views=60)
# 3066 Row(tags=['java'], year=2019, views=24638)
# 3067 Row(tags=['powershell'], year=2016, views=1375)
# 3068 Row(tags=['javascript'], year=2016, views=343)
# 3069 Row(tags=['javascript'], year=2016, views=531)
# 3070 Row(tags=['javascript'], year=2016, views=476)
# 3071 Row(tags=['java'], year=2016, views=544)
# 3072 Row(tags=['r'], year=2017, views=927)
# 3073 Row(tags=['powershell'], year=2016, views=608)
# 3074 Row(tags=['objective-c'], year=2016, views=287)
# 3075 Row(tags=['java'], year=2018, views=8022)
# 3076 Row(tags=['javascript'], year=2016, views=682)
# 3077 Row(tags=['javascript'], year=2016, views=29)
# 3078 Row(tags=['java'], year=2016, views=355)
# 3079 Row(tags=['java'], year=2016, views=688)
# 3080 Row(tags=['javascript'], year=2016, views=54)
# 3081 Row(tags=['c'], year=2016, views=97)
# 3082 Row(tags=['javascript'], year=2016, views=67)
# 3083 Row(tags=['javascript'], year=2016, views=600)
# 3084 Row(tags=['r'], year=2019, views=1800)
# 3085 Row(tags=['python'], year=2016, views=481)
# 3086 Row(tags=['java'], year=2016, views=575)
# 3087 Row(tags=['java'], year=2016, views=1248)
# 3088 Row(tags=['java'], year=2016, views=642)
# 3089 Row(tags=['lua'], year=2017, views=484)
# 3090 Row(tags=['sed'], year=2017, views=51)
# 3091 Row(tags=['php'], year=2017, views=1710)
# 3092 Row(tags=['php'], year=2017, views=63)
# 3093 Row(tags=['java'], year=2017, views=140)
# 3094 Row(tags=['javascript'], year=2017, views=352)
# 3095 Row(tags=['scala'], year=2017, views=29)
# 3096 Row(tags=['java'], year=2017, views=543)
# 3097 Row(tags=['bash'], year=2017, views=665)
# 3098 Row(tags=['perl'], year=2018, views=118)
# 3099 Row(tags=['php'], year=2017, views=16)
# 3100 Row(tags=['java'], year=2017, views=76)
# 3101 Row(tags=['objective-c'], year=2018, views=513)
# 3102 Row(tags=['javascript'], year=2017, views=203)
# 3103 Row(tags=['lua'], year=2017, views=127)
# 3104 Row(tags=['javascript'], year=2017, views=882)
# 3105 Row(tags=['java'], year=2017, views=75)
# 3106 Row(tags=['php'], year=2017, views=35)
# 3107 Row(tags=['java'], year=2017, views=504)
# 3108 Row(tags=['python'], year=2018, views=741)
# 3109 Row(tags=['python'], year=2017, views=117)
# 3110 Row(tags=['basic'], year=2017, views=76)
# 3111 Row(tags=['python'], year=2018, views=392)
# 3112 Row(tags=['php'], year=2017, views=41)
# 3113 Row(tags=['python'], year=2017, views=332)
# 3114 Row(tags=['java'], year=2017, views=108)
# 3115 Row(tags=['r'], year=2018, views=170)
# 3116 Row(tags=['python'], year=2017, views=99)
# 3117 Row(tags=['java'], year=2017, views=426)
# 3118 Row(tags=['java'], year=2017, views=105)
# 3119 Row(tags=['javascript', 'php'], year=2017, views=31)
# 3120 Row(tags=['ruby'], year=2018, views=197)
# 3121 Row(tags=['r'], year=2018, views=314)
# 3122 Row(tags=['python'], year=2018, views=254)
# 3123 Row(tags=['javascript'], year=2018, views=36)
# 3124 Row(tags=['kotlin'], year=2018, views=3036)
# 3125 Row(tags=['java'], year=2018, views=121)
# 3126 Row(tags=['javascript', 'bash'], year=2018, views=446)
# 3127 Row(tags=['javascript'], year=2018, views=65)
# 3128 Row(tags=['r', 'latex'], year=2018, views=105)
# 3129 Row(tags=['javascript'], year=2018, views=15)
# 3130 Row(tags=['python'], year=2018, views=78)
# 3131 Row(tags=['r'], year=2018, views=53)
# 3132 Row(tags=['bash'], year=2018, views=51)
# 3133 Row(tags=['python'], year=2018, views=272)
# 3134 Row(tags=['php'], year=2018, views=74)
# 3135 Row(tags=['python'], year=2018, views=45)
# 3136 Row(tags=['php'], year=2018, views=96)
# 3137 Row(tags=['php'], year=2018, views=46)
# 3138 Row(tags=['javascript'], year=2018, views=27)
# 3139 Row(tags=['javascript'], year=2018, views=25)
# 3140 Row(tags=['python'], year=2018, views=78)
# 3141 Row(tags=['r'], year=2019, views=418)
# 3142 Row(tags=['php'], year=2018, views=38)
# 3143 Row(tags=['java'], year=2018, views=45)
# 3144 Row(tags=['python'], year=2018, views=39)
# 3145 Row(tags=['r'], year=2018, views=36)
# 3146 Row(tags=['python'], year=2018, views=34)
# 3147 Row(tags=['python'], year=2018, views=533)
# 3148 Row(tags=['python'], year=2018, views=42)
# 3149 Row(tags=['curl', 'coldfusion'], year=2018, views=63)
# 3150 Row(tags=['javascript'], year=2018, views=20)
# 3151 Row(tags=['python'], year=2018, views=37)
# 3152 Row(tags=['kotlin'], year=2018, views=58)
# 3153 Row(tags=['python'], year=2018, views=62)
# 3154 Row(tags=['c'], year=2019, views=25)
# 3155 Row(tags=['r'], year=2019, views=70)
# 3156 Row(tags=['javascript'], year=2019, views=102)
# 3157 Row(tags=['java'], year=2019, views=94)
# 3158 Row(tags=['python'], year=2019, views=14)
# 3159 Row(tags=['java'], year=2019, views=61)
# 3160 Row(tags=['javascript'], year=2019, views=24)
# 3161 Row(tags=['scala'], year=2019, views=33)
# 3162 Row(tags=['php'], year=2019, views=45)
# 3163 Row(tags=['javascript'], year=2019, views=41)
# 3164 Row(tags=['matlab'], year=2019, views=37)
# 3165 Row(tags=['php'], year=2019, views=41)
# 3166 Row(tags=['python'], year=2019, views=27)
# 3167 Row(tags=['python'], year=2019, views=48)
# 3168 Row(tags=['python'], year=2019, views=45)
# 3169 Row(tags=['java'], year=2019, views=59)
# 3170 Row(tags=['java'], year=2019, views=16)
# 3171 Row(tags=['python'], year=2019, views=17)
# 3172 Row(tags=['c'], year=2019, views=77)
# 3173 Row(tags=['php'], year=2019, views=40)
# 3174 Row(tags=['bash', 'awk'], year=2019, views=41)
# 3175 Row(tags=['objective-c'], year=2019, views=82)
# 3176 Row(tags=['java'], year=2019, views=74)
# 3177 Row(tags=['go'], year=2019, views=78)
# 3178 Row(tags=['java'], year=2019, views=27)
# 3179 Row(tags=['java'], year=2019, views=38)
# 3180 Row(tags=['netlogo'], year=2019, views=26)
# 3181 Row(tags=['r'], year=2019, views=7)
# 3182 Row(tags=['python'], year=2019, views=15)
# 3183 Row(tags=['bash'], year=2019, views=44)
# 3184 Row(tags=['javascript'], year=2012, views=11833)
# 3185 Row(tags=['bash'], year=2012, views=446)
# 3186 Row(tags=['php'], year=2013, views=7908)
# 3187 Row(tags=['javascript'], year=2012, views=472)
# 3188 Row(tags=['java'], year=2012, views=1087)
# 3189 Row(tags=['r'], year=2012, views=3830)
# 3190 Row(tags=['javascript'], year=2012, views=1366)
# 3191 Row(tags=['lua'], year=2013, views=5939)
# 3192 Row(tags=['javascript'], year=2012, views=1643)
# 3193 Row(tags=['php'], year=2012, views=4286)
# 3194 Row(tags=['java'], year=2012, views=1620)
# 3195 Row(tags=['java'], year=2012, views=649)
# 3196 Row(tags=['c', 'perl'], year=2012, views=1011)
# 3197 Row(tags=['php'], year=2012, views=3400)
# 3198 Row(tags=['java'], year=2012, views=4910)
# 3199 Row(tags=['objective-c'], year=2012, views=4281)
# 3200 Row(tags=['java'], year=2013, views=623)
# 3201 Row(tags=['python'], year=2012, views=3431)
# 3202 Row(tags=['python'], year=2013, views=274)
# 3203 Row(tags=['javascript'], year=2013, views=67)
# 3204 Row(tags=['python'], year=2014, views=1421)
# 3205 Row(tags=['php'], year=2014, views=13648)
# 3206 Row(tags=['python'], year=2013, views=140)
# 3207 Row(tags=['ruby'], year=2015, views=7441)
# 3208 Row(tags=['php'], year=2012, views=458)
# 3209 Row(tags=['python'], year=2012, views=429)
# 3210 Row(tags=['lua'], year=2012, views=2541)
# 3211 Row(tags=['php'], year=2012, views=4017)
# 3212 Row(tags=['javascript'], year=2012, views=868)
# 3213 Row(tags=['java'], year=2014, views=756)
# 3214 Row(tags=['javascript'], year=2012, views=1153)
# 3215 Row(tags=['php', 'ruby'], year=2012, views=452)
# 3216 Row(tags=['php'], year=2018, views=533)
# 3217 Row(tags=['java'], year=2012, views=152)
# 3218 Row(tags=['java'], year=2016, views=12336)
# 3219 Row(tags=['php'], year=2012, views=97)
# 3220 Row(tags=['javascript'], year=2011, views=1018)
# 3221 Row(tags=['objective-c'], year=2011, views=773)
# 3222 Row(tags=['matlab'], year=2011, views=2497)
# 3223 Row(tags=['python'], year=2011, views=199)
# 3224 Row(tags=['python'], year=2011, views=839)
# 3225 Row(tags=['objective-c'], year=2011, views=85)
# 3226 Row(tags=['java', 'xpath'], year=2011, views=481)
# 3227 Row(tags=['python'], year=2019, views=1872)
# 3228 Row(tags=['php'], year=2011, views=48)
# 3229 Row(tags=['c'], year=2011, views=287)
# 3230 Row(tags=['javascript'], year=2017, views=45593)
# 3231 Row(tags=['php'], year=2012, views=200)
# 3232 Row(tags=['java'], year=2011, views=771)
# 3233 Row(tags=['php'], year=2011, views=407)
# 3234 Row(tags=['javascript'], year=2011, views=458)
# 3235 Row(tags=['actionscript'], year=2012, views=2254)
# 3236 Row(tags=['cil'], year=2017, views=102)
# 3237 Row(tags=['python'], year=2016, views=361)
# 3238 Row(tags=['javascript'], year=2015, views=33)
# 3239 Row(tags=['javascript'], year=2017, views=290)
# 3240 Row(tags=['ruby'], year=2015, views=21)
# 3241 Row(tags=['php'], year=2016, views=3243)
# 3242 Row(tags=['java'], year=2018, views=1389)
# 3243 Row(tags=['javascript'], year=2016, views=842)
# 3244 Row(tags=['c'], year=2016, views=139)
# 3245 Row(tags=['java'], year=2016, views=151)
# 3246 Row(tags=['java'], year=2016, views=59)
# 3247 Row(tags=['javascript', 'php'], year=2016, views=223)
# 3248 Row(tags=['java'], year=2017, views=2483)
# 3249 Row(tags=['php'], year=2016, views=41)
# 3250 Row(tags=['objective-c'], year=2016, views=274)
# 3251 Row(tags=['python'], year=2016, views=235)
# 3252 Row(tags=['awk'], year=2016, views=49)
# 3253 Row(tags=['powershell'], year=2016, views=9500)
# 3254 Row(tags=['javascript'], year=2016, views=29)
# 3255 Row(tags=['awk', 'sed'], year=2016, views=1262)
# 3256 Row(tags=['java'], year=2016, views=446)
# 3257 Row(tags=['java'], year=2016, views=1217)
# 3258 Row(tags=['javascript'], year=2016, views=55)
# 3259 Row(tags=['javascript'], year=2012, views=1299)
# 3260 Row(tags=['php'], year=2012, views=983)
# 3261 Row(tags=['java'], year=2012, views=161)
# 3262 Row(tags=['javascript'], year=2016, views=93206)
# 3263 Row(tags=['java'], year=2012, views=381)
# 3264 Row(tags=['java'], year=2012, views=119)
# 3265 Row(tags=['php'], year=2012, views=731)
# 3266 Row(tags=['r'], year=2019, views=28875)
# 3267 Row(tags=['javascript'], year=2012, views=974)
# 3268 Row(tags=['python'], year=2012, views=1125)
# 3269 Row(tags=['javascript'], year=2012, views=271)
# 3270 Row(tags=['php'], year=2012, views=2044)
# 3271 Row(tags=['c'], year=2012, views=295)
# 3272 Row(tags=['c'], year=2019, views=1310)
# 3273 Row(tags=['javascript'], year=2012, views=374)
# 3274 Row(tags=['php'], year=2012, views=241)
# 3275 Row(tags=['ruby'], year=2012, views=371)
# 3276 Row(tags=['f#'], year=2012, views=825)
# 3277 Row(tags=['javascript'], year=2012, views=720)
# 3278 Row(tags=['python'], year=2012, views=1225)
# 3279 Row(tags=['java'], year=2012, views=562)
# 3280 Row(tags=['javascript'], year=2012, views=138)
# 3281 Row(tags=['f#'], year=2012, views=397)
# 3282 Row(tags=['java', 'xpath'], year=2017, views=17226)
# 3283 Row(tags=['ruby'], year=2012, views=45)
# 3284 Row(tags=['php', 'javascript'], year=2012, views=262)
# 3285 Row(tags=['powershell'], year=2017, views=54)
# 3286 Row(tags=['r'], year=2017, views=265)
# 3287 Row(tags=['php'], year=2017, views=39)
# 3288 Row(tags=['python'], year=2018, views=88)
# 3289 Row(tags=['php'], year=2017, views=127)
# 3290 Row(tags=['c'], year=2017, views=113)
# 3291 Row(tags=['java'], year=2019, views=12687)
# 3292 Row(tags=['java'], year=2017, views=76)
# 3293 Row(tags=['python'], year=2018, views=78)
# 3294 Row(tags=['javascript'], year=2017, views=241)
# 3295 Row(tags=['java'], year=2017, views=56)
# 3296 Row(tags=['r'], year=2017, views=173)
# 3297 Row(tags=['python'], year=2017, views=361)
# 3298 Row(tags=['java'], year=2017, views=639)
# 3299 Row(tags=['javascript'], year=2017, views=944)
# 3300 Row(tags=['r'], year=2017, views=224)
# 3301 Row(tags=['javascript'], year=2017, views=1175)
# 3302 Row(tags=['curl'], year=2017, views=41)
# 3303 Row(tags=['elixir'], year=2018, views=379)
# 3304 Row(tags=['python'], year=2017, views=246)
# 3305 Row(tags=['javascript'], year=2017, views=258)
# 3306 Row(tags=['php'], year=2017, views=38)
# 3307 Row(tags=['javascript'], year=2017, views=210)
# 3308 Row(tags=['python'], year=2018, views=1729)
# 3309 Row(tags=['php'], year=2017, views=36)
# 3310 Row(tags=['ruby'], year=2017, views=747)
# 3311 Row(tags=['python'], year=2018, views=31)
# 3312 Row(tags=['javascript'], year=2018, views=259)
# 3313 Row(tags=['php'], year=2018, views=53)
# 3314 Row(tags=['javascript'], year=2018, views=39)
# 3315 Row(tags=['python'], year=2015, views=1192)
# 3316 Row(tags=['javascript'], year=2013, views=46)
# 3317 Row(tags=['php'], year=2013, views=882)
# 3318 Row(tags=['java'], year=2013, views=879)
# 3319 Row(tags=['powershell'], year=2015, views=1046)
# 3320 Row(tags=['lua'], year=2013, views=134)
# 3321 Row(tags=['javascript'], year=2013, views=441)
# 3322 Row(tags=['java'], year=2014, views=2892)
# 3323 Row(tags=['objective-c'], year=2013, views=599)
# 3324 Row(tags=['php'], year=2013, views=133)
# 3325 Row(tags=['javascript'], year=2014, views=366)
# 3326 Row(tags=['php'], year=2013, views=99)
# 3327 Row(tags=['python'], year=2015, views=3980)
# 3328 Row(tags=['javascript'], year=2013, views=135)
# 3329 Row(tags=['ruby'], year=2013, views=530)
# 3330 Row(tags=['objective-c'], year=2014, views=1351)
# 3331 Row(tags=['java'], year=2017, views=14217)
# 3332 Row(tags=['php'], year=2018, views=7412)
# 3333 Row(tags=['objective-c'], year=2013, views=158)
# 3334 Row(tags=['java'], year=2015, views=3846)
# 3335 Row(tags=['javascript'], year=2013, views=1135)
# 3336 Row(tags=['r'], year=2013, views=115)
# 3337 Row(tags=['objective-c'], year=2015, views=8506)
# 3338 Row(tags=['java'], year=2013, views=842)
# 3339 Row(tags=['php'], year=2013, views=475)
# 3340 Row(tags=['php', 'curl'], year=2013, views=249)
# 3341 Row(tags=['php', 'javascript'], year=2013, views=147)
# 3342 Row(tags=['r'], year=2013, views=320)
# 3343 Row(tags=['javascript'], year=2013, views=452)
# 3344 Row(tags=['java'], year=2014, views=3181)
# 3345 Row(tags=['r'], year=2013, views=483)
# 3346 Row(tags=['java'], year=2013, views=1545)
# 3347 Row(tags=['javascript'], year=2014, views=48)
# 3348 Row(tags=['java'], year=2018, views=1501)
# 3349 Row(tags=['java'], year=2014, views=55)
# 3350 Row(tags=['perl'], year=2014, views=110)
# 3351 Row(tags=['javascript'], year=2014, views=2514)
# 3352 Row(tags=['php'], year=2014, views=2291)
# 3353 Row(tags=['python'], year=2014, views=313)
# 3354 Row(tags=['php', 'xpath'], year=2014, views=332)
# 3355 Row(tags=['java'], year=2016, views=3116)
# 3356 Row(tags=['javascript'], year=2014, views=1974)
# 3357 Row(tags=['python'], year=2015, views=226)
# 3358 Row(tags=['python'], year=2018, views=366)
# 3359 Row(tags=['php'], year=2015, views=43)
# 3360 Row(tags=['c'], year=2014, views=1136)
# 3361 Row(tags=['ruby'], year=2014, views=577)
# 3362 Row(tags=['python'], year=2014, views=44)
# 3363 Row(tags=['javascript'], year=2014, views=638)
# 3364 Row(tags=['python'], year=2014, views=215)
# 3365 Row(tags=['matlab'], year=2016, views=402)
# 3366 Row(tags=['scala'], year=2014, views=322)
# 3367 Row(tags=['applescript'], year=2014, views=1468)
# 3368 Row(tags=['xpath'], year=2014, views=1608)
# 3369 Row(tags=['javascript'], year=2015, views=68)
# 3370 Row(tags=['c', 'opencl'], year=2015, views=104)
# 3371 Row(tags=['php'], year=2015, views=47)
# 3372 Row(tags=['python'], year=2015, views=92)
# 3373 Row(tags=['scala'], year=2017, views=1799)
# 3374 Row(tags=['php'], year=2015, views=38)
# 3375 Row(tags=['php'], year=2017, views=443)
# 3376 Row(tags=['php'], year=2011, views=344)
# 3377 Row(tags=['python'], year=2011, views=931)
# 3378 Row(tags=['php'], year=2011, views=369)
# 3379 Row(tags=['java'], year=2011, views=1988)
# 3380 Row(tags=['java'], year=2017, views=61769)
# 3381 Row(tags=['objective-c'], year=2011, views=204)
# 3382 Row(tags=['javascript'], year=2017, views=3800)
# 3383 Row(tags=['javascript'], year=2018, views=71045)
# 3384 Row(tags=['php'], year=2012, views=1905)
# 3385 Row(tags=['java'], year=2011, views=213)
# 3386 Row(tags=['javascript'], year=2011, views=104)
# 3387 Row(tags=['php'], year=2012, views=4743)
# 3388 Row(tags=['javascript'], year=2019, views=175217)
# 3389 Row(tags=['cuda'], year=2016, views=2428)
# 3390 Row(tags=['javascript'], year=2015, views=977)
# 3391 Row(tags=['cuda'], year=2011, views=1456)
# 3392 Row(tags=['javascript'], year=2011, views=1314)
# 3393 Row(tags=['javascript'], year=2012, views=1116)
# 3394 Row(tags=['javascript'], year=2014, views=3122)
# 3395 Row(tags=['java'], year=2011, views=59)
# 3396 Row(tags=['php'], year=2011, views=921)
# 3397 Row(tags=['javascript'], year=2011, views=1888)
# 3398 Row(tags=['javascript'], year=2011, views=291)
# 3399 Row(tags=['objective-c'], year=2011, views=2068)
# 3400 Row(tags=['javascript'], year=2011, views=177)
# 3401 Row(tags=['objective-c'], year=2011, views=168)
# 3402 Row(tags=['javascript'], year=2019, views=196275)
# 3403 Row(tags=['java'], year=2011, views=84)
# 3404 Row(tags=['java'], year=2011, views=15015)
# 3405 Row(tags=['bash'], year=2018, views=2260)
# 3406 Row(tags=['ruby'], year=2011, views=75)
# 3407 Row(tags=['c'], year=2011, views=727)
# 3408 Row(tags=['javascript'], year=2015, views=74)
# 3409 Row(tags=['java'], year=2015, views=41)
# 3410 Row(tags=['java'], year=2015, views=248)
# 3411 Row(tags=['javascript'], year=2015, views=30)
# 3412 Row(tags=['java'], year=2015, views=2398)
# 3413 Row(tags=['ruby'], year=2015, views=1476)
# 3414 Row(tags=['javascript'], year=2015, views=28)
# 3415 Row(tags=['java'], year=2015, views=467)
# 3416 Row(tags=['python'], year=2015, views=58)
# 3417 Row(tags=['javascript'], year=2015, views=154)
# 3418 Row(tags=['python'], year=2017, views=15787)
# 3419 Row(tags=['perl'], year=2017, views=724)
# 3420 Row(tags=['bash', 'awk'], year=2015, views=449)
# 3421 Row(tags=['java'], year=2018, views=1215)
# 3422 Row(tags=['java'], year=2015, views=220)
# 3423 Row(tags=['java'], year=2015, views=347)
# 3424 Row(tags=['javascript'], year=2015, views=69)
# 3425 Row(tags=['javascript'], year=2015, views=1143)
# 3426 Row(tags=['javascript'], year=2015, views=155)
# 3427 Row(tags=['java'], year=2015, views=795)
# 3428 Row(tags=['javascript', 'java'], year=2015, views=500)
# 3429 Row(tags=['java'], year=2015, views=26)
# 3430 Row(tags=['java'], year=2015, views=3649)
# 3431 Row(tags=['javascript'], year=2015, views=120)
# 3432 Row(tags=['ruby'], year=2015, views=61)
# 3433 Row(tags=['java'], year=2015, views=43)
# 3434 Row(tags=['php'], year=2015, views=137)
# 3435 Row(tags=['javascript'], year=2015, views=161)
# 3436 Row(tags=['python'], year=2015, views=307)
# 3437 Row(tags=['php'], year=2015, views=56)
# 3438 Row(tags=['python'], year=2015, views=87)
# 3439 Row(tags=['java'], year=2019, views=123)
# 3440 Row(tags=['javascript'], year=2016, views=1644)
# 3441 Row(tags=['bash'], year=2016, views=854)
# 3442 Row(tags=['javascript'], year=2016, views=42)
# 3443 Row(tags=['python'], year=2016, views=382)
# 3444 Row(tags=['java'], year=2016, views=1274)
# 3445 Row(tags=['python'], year=2017, views=781)
# 3446 Row(tags=['java'], year=2016, views=36)
# 3447 Row(tags=['javascript'], year=2016, views=26)
# 3448 Row(tags=['octave'], year=2016, views=143)
# 3449 Row(tags=['java'], year=2016, views=131)
# 3450 Row(tags=['java'], year=2016, views=56)
# 3451 Row(tags=['php'], year=2016, views=126)
# 3452 Row(tags=['c'], year=2016, views=93)
# 3453 Row(tags=['python'], year=2016, views=58)
# 3454 Row(tags=['python'], year=2016, views=2131)
# 3455 Row(tags=['javascript'], year=2016, views=530)
# 3456 Row(tags=['javascript'], year=2016, views=91)
# 3457 Row(tags=['javascript', 'php'], year=2016, views=108)
# 3458 Row(tags=['java'], year=2016, views=76)
# 3459 Row(tags=['php'], year=2016, views=148)
# 3460 Row(tags=['lua'], year=2016, views=174)
# 3461 Row(tags=['javascript'], year=2016, views=324)
# 3462 Row(tags=['javascript'], year=2016, views=93)
# 3463 Row(tags=['python'], year=2017, views=194)
# 3464 Row(tags=['javascript'], year=2016, views=42)
# 3465 Row(tags=['c'], year=2016, views=155)
# 3466 Row(tags=['php'], year=2016, views=148)
# 3467 Row(tags=['r'], year=2016, views=3834)
# 3468 Row(tags=['php'], year=2017, views=28)
# 3469 Row(tags=['php'], year=2017, views=142)
# 3470 Row(tags=['java'], year=2017, views=1594)
# 3471 Row(tags=['java'], year=2018, views=59)
# 3472 Row(tags=['java'], year=2017, views=50)
# 3473 Row(tags=['java'], year=2017, views=511)
# 3474 Row(tags=['python'], year=2017, views=52)
# 3475 Row(tags=['javascript'], year=2017, views=197)
# 3476 Row(tags=['matlab'], year=2017, views=68)
# 3477 Row(tags=['javascript'], year=2017, views=45)
# 3478 Row(tags=['php'], year=2017, views=25)
# 3479 Row(tags=['javascript'], year=2017, views=460)
# 3480 Row(tags=['python'], year=2017, views=127)
# 3481 Row(tags=['r'], year=2017, views=67)
# 3482 Row(tags=['java'], year=2017, views=81)
# 3483 Row(tags=['javascript'], year=2017, views=186)
# 3484 Row(tags=['javascript'], year=2017, views=233)
# 3485 Row(tags=['php'], year=2017, views=66)
# 3486 Row(tags=['typescript'], year=2017, views=369)
# 3487 Row(tags=['javascript'], year=2017, views=256)
# 3488 Row(tags=['python'], year=2017, views=375)
# 3489 Row(tags=['php'], year=2017, views=80)
# 3490 Row(tags=['php'], year=2017, views=236)
# 3491 Row(tags=['python', 'r'], year=2017, views=59)
# 3492 Row(tags=['javascript'], year=2017, views=299)
# 3493 Row(tags=['javascript'], year=2017, views=49)
# 3494 Row(tags=['java'], year=2017, views=98)
# 3495 Row(tags=['java'], year=2017, views=970)
# 3496 Row(tags=['scala'], year=2017, views=1818)
# 3497 Row(tags=['lua'], year=2017, views=231)
# 3498 Row(tags=['php'], year=2016, views=521)
# 3499 Row(tags=['javascript'], year=2010, views=326)
# 3500 Row(tags=['delphi'], year=2017, views=4446)
# 3501 Row(tags=['php'], year=2010, views=741)
# 3502 Row(tags=['javascript'], year=2010, views=147)
# 3503 Row(tags=['java'], year=2010, views=7650)
# 3504 Row(tags=['objective-c'], year=2018, views=29885)
# 3505 Row(tags=['java'], year=2010, views=1279)
# 3506 Row(tags=['java'], year=2010, views=536)
# 3507 Row(tags=['ruby'], year=2011, views=711)
# 3508 Row(tags=['xpath'], year=2010, views=5122)
# 3509 Row(tags=['java'], year=2018, views=240129)
# 3510 Row(tags=['java'], year=2018, views=86271)
# 3511 Row(tags=['php'], year=2010, views=7188)
# 3512 Row(tags=['java'], year=2013, views=613)
# 3513 Row(tags=['php'], year=2010, views=140)
# 3514 Row(tags=['php', 'javascript'], year=2010, views=615)
# 3515 Row(tags=['c'], year=2012, views=2815)
# 3516 Row(tags=['c'], year=2010, views=158)
# 3517 Row(tags=['java'], year=2010, views=5105)
# 3518 Row(tags=['php'], year=2011, views=591)
# 3519 Row(tags=['java'], year=2010, views=1756)
# 3520 Row(tags=['javascript'], year=2010, views=703)
# 3521 Row(tags=['python'], year=2010, views=667)
# 3522 Row(tags=['javascript'], year=2017, views=8967)
# 3523 Row(tags=['java'], year=2011, views=593)
# 3524 Row(tags=['actionscript'], year=2010, views=5104)
# 3525 Row(tags=['delphi'], year=2014, views=939)
# 3526 Row(tags=['java'], year=2010, views=476)
# 3527 Row(tags=['php', 'javascript'], year=2010, views=2152)
# 3528 Row(tags=['python'], year=2012, views=384)
# 3529 Row(tags=['python'], year=2010, views=839)
# 3530 Row(tags=['php'], year=2013, views=957)
# 3531 Row(tags=['javascript'], year=2013, views=104)
# 3532 Row(tags=['java'], year=2016, views=287)
# 3533 Row(tags=['java', 'php'], year=2013, views=230)
# 3534 Row(tags=['php'], year=2013, views=1796)
# 3535 Row(tags=['java'], year=2013, views=217)
# 3536 Row(tags=['ruby'], year=2013, views=214)
# 3537 Row(tags=['bash', 'sed'], year=2013, views=1375)
# 3538 Row(tags=['java'], year=2013, views=4319)
# 3539 Row(tags=['java'], year=2013, views=188)
# 3540 Row(tags=['sas'], year=2013, views=161)
# 3541 Row(tags=['python'], year=2013, views=1110)
# 3542 Row(tags=['java'], year=2014, views=8383)
# 3543 Row(tags=['java'], year=2014, views=353)
# 3544 Row(tags=['python'], year=2013, views=291)
# 3545 Row(tags=['php'], year=2013, views=74)
# 3546 Row(tags=['python'], year=2013, views=109)
# 3547 Row(tags=['javascript'], year=2013, views=476)
# 3548 Row(tags=['java'], year=2013, views=1483)
# 3549 Row(tags=['python'], year=2013, views=949)
# 3550 Row(tags=['java'], year=2013, views=395)
# 3551 Row(tags=['ruby'], year=2013, views=71)
# 3552 Row(tags=['php'], year=2013, views=1174)
# 3553 Row(tags=['php'], year=2013, views=1142)
# 3554 Row(tags=['php'], year=2013, views=1405)
# 3555 Row(tags=['java'], year=2013, views=8380)
# 3556 Row(tags=['javascript'], year=2013, views=3830)
# 3557 Row(tags=['sas'], year=2013, views=1624)
# 3558 Row(tags=['javascript'], year=2013, views=496)
# 3559 Row(tags=['javascript'], year=2013, views=702)
# 3560 Row(tags=['java'], year=2019, views=328)
# 3561 Row(tags=['python'], year=2018, views=48)
# 3562 Row(tags=['scala'], year=2018, views=69)
# 3563 Row(tags=['python'], year=2018, views=471)
# 3564 Row(tags=['typescript'], year=2018, views=305)
# 3565 Row(tags=['php', 'python'], year=2018, views=30)
# 3566 Row(tags=['delphi'], year=2018, views=1295)
# 3567 Row(tags=['javascript'], year=2018, views=433)
# 3568 Row(tags=['python'], year=2019, views=376)
# 3569 Row(tags=['python'], year=2018, views=31)
# 3570 Row(tags=['scala'], year=2018, views=42)
# 3571 Row(tags=['perl6'], year=2018, views=109)
# 3572 Row(tags=['python'], year=2018, views=61)
# 3573 Row(tags=['c'], year=2018, views=53)
# 3574 Row(tags=['php'], year=2018, views=51)
# 3575 Row(tags=['mouse'], year=2018, views=175)
# 3576 Row(tags=['javascript'], year=2018, views=76)
# 3577 Row(tags=['javascript'], year=2018, views=52)
# 3578 Row(tags=['python'], year=2018, views=48)
# 3579 Row(tags=['r'], year=2018, views=904)
# 3580 Row(tags=['python', 'r'], year=2018, views=473)
# 3581 Row(tags=['java'], year=2018, views=42)
# 3582 Row(tags=['typescript'], year=2018, views=473)
# 3583 Row(tags=['python'], year=2019, views=45)
# 3584 Row(tags=['javascript'], year=2019, views=77)
# 3585 Row(tags=['python'], year=2019, views=39)
# 3586 Row(tags=['python'], year=2019, views=40)
# 3587 Row(tags=['kotlin'], year=2019, views=24)
# 3588 Row(tags=['java'], year=2019, views=34)
# 3589 Row(tags=['python'], year=2019, views=24)
# 3590 Row(tags=['php'], year=2019, views=45)
# 3591 Row(tags=['javascript'], year=2019, views=31)
# 3592 Row(tags=['python'], year=2019, views=29)
# 3593 Row(tags=['java'], year=2019, views=86)
# 3594 Row(tags=['f#'], year=2019, views=45)
# 3595 Row(tags=['javascript'], year=2019, views=23)
# 3596 Row(tags=['javascript', 'typescript'], year=2019, views=353)
# 3597 Row(tags=['c'], year=2019, views=45)
# 3598 Row(tags=['javascript'], year=2019, views=71)
# 3599 Row(tags=['php'], year=2019, views=54)
# 3600 Row(tags=['javascript'], year=2019, views=16)
# 3601 Row(tags=['python'], year=2019, views=34)
# 3602 Row(tags=['dart'], year=2019, views=34)
# 3603 Row(tags=['javascript'], year=2019, views=47)
# 3604 Row(tags=['javascript'], year=2019, views=60)
# 3605 Row(tags=['python'], year=2019, views=34)
# 3606 Row(tags=['matlab'], year=2012, views=126)
# 3607 Row(tags=['javascript'], year=2012, views=149)
# 3608 Row(tags=['python'], year=2013, views=12913)
# 3609 Row(tags=['objective-c'], year=2012, views=187)
# 3610 Row(tags=['python'], year=2013, views=2700)
# 3611 Row(tags=['python'], year=2014, views=6735)
# 3612 Row(tags=['java'], year=2012, views=3076)
# 3613 Row(tags=['javascript'], year=2018, views=2200)
# 3614 Row(tags=['java'], year=2012, views=1347)
# 3615 Row(tags=['java'], year=2012, views=253)
# 3616 Row(tags=['bash'], year=2012, views=159)
# 3617 Row(tags=['php'], year=2012, views=361)
# 3618 Row(tags=['java'], year=2012, views=979)
# 3619 Row(tags=['python'], year=2013, views=16551)
# 3620 Row(tags=['php'], year=2017, views=4941)
# 3621 Row(tags=['php'], year=2012, views=14011)
# 3622 Row(tags=['javascript'], year=2012, views=942)
# 3623 Row(tags=['php'], year=2012, views=800)
# 3624 Row(tags=['php', 'javascript'], year=2012, views=2562)
# 3625 Row(tags=['java'], year=2012, views=5557)
# 3626 Row(tags=['python'], year=2012, views=394)
# 3627 Row(tags=['python'], year=2012, views=34572)
# 3628 Row(tags=['java'], year=2012, views=133)
# 3629 Row(tags=['javascript'], year=2012, views=382)
# 3630 Row(tags=['python'], year=2012, views=915)
# 3631 Row(tags=['php'], year=2012, views=550)
# 3632 Row(tags=['python'], year=2012, views=229)
# 3633 Row(tags=['javascript'], year=2012, views=211)
# 3634 Row(tags=['php'], year=2012, views=222)
# 3635 Row(tags=['ruby'], year=2012, views=300)
# 3636 Row(tags=['javascript'], year=2013, views=2133)
# 3637 Row(tags=['clojure'], year=2013, views=346)
# 3638 Row(tags=['javascript'], year=2013, views=930)
# 3639 Row(tags=['java'], year=2018, views=1694)
# 3640 Row(tags=['ruby'], year=2013, views=167)
# 3641 Row(tags=['bash'], year=2015, views=2842)
# 3642 Row(tags=['python'], year=2013, views=1835)
# 3643 Row(tags=['php'], year=2013, views=631)
# 3644 Row(tags=['php'], year=2013, views=118)
# 3645 Row(tags=['matlab'], year=2013, views=152)
# 3646 Row(tags=['java'], year=2013, views=541)
# 3647 Row(tags=['java'], year=2015, views=3092)
# 3648 Row(tags=['php'], year=2013, views=1809)
# 3649 Row(tags=['javascript'], year=2014, views=4142)
# 3650 Row(tags=['perl'], year=2017, views=213)
# 3651 Row(tags=['java'], year=2013, views=381)
# 3652 Row(tags=['bash', 'awk'], year=2013, views=1008)
# 3653 Row(tags=['bash'], year=2014, views=287)
# 3654 Row(tags=['java'], year=2013, views=70)
# 3655 Row(tags=['python', 'scala'], year=2013, views=47)
# 3656 Row(tags=['c'], year=2013, views=112)
# 3657 Row(tags=['javascript'], year=2013, views=281)
# 3658 Row(tags=['sas'], year=2013, views=5110)
# 3659 Row(tags=['java'], year=2013, views=1712)
# 3660 Row(tags=['c'], year=2013, views=1228)
# 3661 Row(tags=['javascript'], year=2016, views=5392)
# 3662 Row(tags=['php'], year=2013, views=60)
# 3663 Row(tags=['php'], year=2013, views=59)
# 3664 Row(tags=['javascript'], year=2013, views=296)
# 3665 Row(tags=['c'], year=2013, views=623)
# 3666 Row(tags=['java'], year=2013, views=2625)
# 3667 Row(tags=['php'], year=2019, views=44712)
# 3668 Row(tags=['php'], year=2013, views=225)
# 3669 Row(tags=['scheme'], year=2019, views=13014)
# 3670 Row(tags=['java'], year=2018, views=109673)
# 3671 Row(tags=['java'], year=2014, views=6423)
# 3672 Row(tags=['java'], year=2014, views=386)
# 3673 Row(tags=['javascript'], year=2014, views=633)
# 3674 Row(tags=['javascript'], year=2015, views=1067)
# 3675 Row(tags=['haskell'], year=2014, views=1089)
# 3676 Row(tags=['javascript'], year=2014, views=500)
# 3677 Row(tags=['perl'], year=2014, views=91)
# 3678 Row(tags=['javascript'], year=2015, views=563)
# 3679 Row(tags=['php'], year=2014, views=314)
# 3680 Row(tags=['objective-c'], year=2014, views=58)
# 3681 Row(tags=['java'], year=2015, views=728)
# 3682 Row(tags=['matlab'], year=2014, views=772)
# 3683 Row(tags=['javascript'], year=2014, views=25)
# 3684 Row(tags=['javascript'], year=2016, views=278)
# 3685 Row(tags=['python'], year=2014, views=93)
# 3686 Row(tags=['php'], year=2014, views=45)
# 3687 Row(tags=['php'], year=2014, views=96)
# 3688 Row(tags=['java'], year=2019, views=353)
# 3689 Row(tags=['php'], year=2014, views=380)
# 3690 Row(tags=['javascript'], year=2015, views=24237)
# 3691 Row(tags=['php'], year=2014, views=88)
# 3692 Row(tags=['java'], year=2014, views=404)
# 3693 Row(tags=['javascript'], year=2014, views=774)
# 3694 Row(tags=['java'], year=2016, views=21422)
# 3695 Row(tags=['c'], year=2014, views=476)
# 3696 Row(tags=['php'], year=2014, views=37)
# 3697 Row(tags=['java'], year=2014, views=50)
# 3698 Row(tags=['python'], year=2016, views=2896)
# 3699 Row(tags=['python'], year=2016, views=1138)
# 3700 Row(tags=['bash', 'awk'], year=2016, views=59)
# 3701 Row(tags=['java'], year=2016, views=31)
# 3702 Row(tags=['ocaml'], year=2016, views=132)
# 3703 Row(tags=['javascript'], year=2016, views=614)
# 3704 Row(tags=['python'], year=2016, views=795)
# 3705 Row(tags=['python'], year=2016, views=1383)
# 3706 Row(tags=['c'], year=2016, views=501)
# 3707 Row(tags=['python'], year=2016, views=51)
# 3708 Row(tags=['javascript'], year=2016, views=111)
# 3709 Row(tags=['c'], year=2016, views=55)
# 3710 Row(tags=['javascript'], year=2016, views=35)
# 3711 Row(tags=['php'], year=2016, views=35)
# 3712 Row(tags=['python'], year=2016, views=59)
# 3713 Row(tags=['javascript'], year=2016, views=42)
# 3714 Row(tags=['javascript'], year=2016, views=62)
# 3715 Row(tags=['java'], year=2016, views=2643)
# 3716 Row(tags=['python'], year=2016, views=192)
# 3717 Row(tags=['objective-c'], year=2016, views=78)
# 3718 Row(tags=['java'], year=2016, views=336)
# 3719 Row(tags=['javascript'], year=2016, views=686)
# 3720 Row(tags=['java'], year=2016, views=1825)
# 3721 Row(tags=['javascript'], year=2016, views=209)
# 3722 Row(tags=['java'], year=2016, views=346)
# 3723 Row(tags=['php', 'curl'], year=2016, views=821)
# 3724 Row(tags=['python'], year=2017, views=177)
# 3725 Row(tags=['php'], year=2016, views=103)
# 3726 Row(tags=['javascript'], year=2017, views=44)
# 3727 Row(tags=['java'], year=2017, views=236)
# 3728 Row(tags=['javascript'], year=2017, views=44)
# 3729 Row(tags=['java'], year=2017, views=78)
# 3730 Row(tags=['python'], year=2018, views=3610)
# 3731 Row(tags=['java'], year=2017, views=40)
# 3732 Row(tags=['java'], year=2018, views=33007)
# 3733 Row(tags=['python'], year=2017, views=335)
# 3734 Row(tags=['javascript'], year=2017, views=27)
# 3735 Row(tags=['objective-c'], year=2017, views=86)
# 3736 Row(tags=['r'], year=2017, views=521)
# 3737 Row(tags=['php'], year=2017, views=35)
# 3738 Row(tags=['javascript'], year=2017, views=2139)
# 3739 Row(tags=['objective-c'], year=2017, views=142)
# 3740 Row(tags=['java'], year=2017, views=31)
# 3741 Row(tags=['java'], year=2018, views=7490)
# 3742 Row(tags=['java'], year=2017, views=26)
# 3743 Row(tags=['java'], year=2017, views=109)
# 3744 Row(tags=['r'], year=2017, views=1499)
# 3745 Row(tags=['javascript'], year=2017, views=30)
# 3746 Row(tags=['java'], year=2019, views=3535)
# 3747 Row(tags=['bash', 'awk'], year=2017, views=572)
# 3748 Row(tags=['java'], year=2017, views=63)
# 3749 Row(tags=['javascript'], year=2017, views=214)
# 3750 Row(tags=['javascript'], year=2017, views=382)
# 3751 Row(tags=['python'], year=2017, views=51)
# 3752 Row(tags=['java'], year=2017, views=512)
# 3753 Row(tags=['python'], year=2017, views=215)
# 3754 Row(tags=['python'], year=2017, views=106)
# 3755 Row(tags=['netlogo'], year=2017, views=96)
# 3756 Row(tags=['java'], year=2017, views=685)
# 3757 Row(tags=['javascript'], year=2017, views=195)
# 3758 Row(tags=['javascript'], year=2017, views=544)
# 3759 Row(tags=['javascript', 'python'], year=2017, views=98)
# 3760 Row(tags=['php'], year=2018, views=54)
# 3761 Row(tags=['javascript'], year=2018, views=97)
# 3762 Row(tags=['scala'], year=2018, views=76)
# 3763 Row(tags=['javascript', 'php'], year=2018, views=64)
# 3764 Row(tags=['xpath'], year=2018, views=53)
# 3765 Row(tags=['powershell'], year=2018, views=4149)
# 3766 Row(tags=['java'], year=2018, views=53)
# 3767 Row(tags=['r'], year=2018, views=41)
# 3768 Row(tags=['java'], year=2018, views=40)
# 3769 Row(tags=['python'], year=2018, views=110)
# 3770 Row(tags=['java'], year=2018, views=2542)
# 3771 Row(tags=['java'], year=2018, views=45)
# 3772 Row(tags=['php'], year=2018, views=921)
# 3773 Row(tags=['python'], year=2018, views=122)
# 3774 Row(tags=['r'], year=2018, views=76)
# 3775 Row(tags=['java'], year=2018, views=221)
# 3776 Row(tags=['r'], year=2018, views=85)
# 3777 Row(tags=['c'], year=2018, views=85)
# 3778 Row(tags=['objective-c'], year=2018, views=37)
# 3779 Row(tags=['java'], year=2018, views=181)
# 3780 Row(tags=['vala'], year=2018, views=41)
# 3781 Row(tags=['java'], year=2018, views=815)
# 3782 Row(tags=['javascript'], year=2018, views=59)
# 3783 Row(tags=['r'], year=2018, views=165)
# 3784 Row(tags=['java'], year=2019, views=70)
# 3785 Row(tags=['php'], year=2019, views=68)
# 3786 Row(tags=['go'], year=2019, views=65)
# 3787 Row(tags=['php'], year=2019, views=47)
# 3788 Row(tags=['python'], year=2019, views=36)
# 3789 Row(tags=['python'], year=2019, views=196)
# 3790 Row(tags=['python'], year=2019, views=32)
# 3791 Row(tags=['javascript'], year=2019, views=37)
# 3792 Row(tags=['javascript'], year=2019, views=56)
# 3793 Row(tags=['javascript'], year=2019, views=21)
# 3794 Row(tags=['javascript'], year=2019, views=27)
# 3795 Row(tags=['python'], year=2019, views=222)
# 3796 Row(tags=['c'], year=2019, views=57)
# 3797 Row(tags=['perl'], year=2019, views=62)
# 3798 Row(tags=['javascript'], year=2019, views=48)
# 3799 Row(tags=['java'], year=2019, views=42)
# 3800 Row(tags=['javascript'], year=2019, views=20)
# 3801 Row(tags=['javascript'], year=2019, views=35)
# 3802 Row(tags=['r'], year=2019, views=58)
# 3803 Row(tags=['python'], year=2019, views=31)
# 3804 Row(tags=['python'], year=2019, views=35)
# 3805 Row(tags=['java'], year=2019, views=105)
# 3806 Row(tags=['php'], year=2019, views=79)
# 3807 Row(tags=['javascript'], year=2019, views=41)
# 3808 Row(tags=['java'], year=2019, views=30)
# 3809 Row(tags=['javascript'], year=2019, views=51)
# 3810 Row(tags=['javascript', 'typescript'], year=2019, views=198)
# 3811 Row(tags=['java'], year=2019, views=21)
# 3812 Row(tags=['javascript'], year=2015, views=85)
# 3813 Row(tags=['javascript'], year=2014, views=840)
# 3814 Row(tags=['ruby'], year=2014, views=107)
# 3815 Row(tags=['java'], year=2019, views=6767)
# 3816 Row(tags=['python'], year=2015, views=2887)
# ...
# 7486 Row(tags=['php'], year=2017, views=72)
# 7487 Row(tags=['php'], year=2017, views=15)
# 7488 Row(tags=['awk', 'sed'], year=2017, views=42)
# 7489 Row(tags=['php'], year=2017, views=351)
# 7490 Row(tags=['java'], year=2017, views=2319)
# 7491 Row(tags=['javascript'], year=2019, views=100)
# 7492 Row(tags=['java'], year=2019, views=31)
# 7493 Row(tags=['python'], year=2019, views=3896)
# 7494 Row(tags=['bash'], year=2019, views=50)
# 7495 Row(tags=['php'], year=2019, views=46)
# 7496 Row(tags=['php'], year=2019, views=44)
# 7497 Row(tags=['php'], year=2019, views=90)
# 7498 Row(tags=['python'], year=2019, views=39)
# 7499 Row(tags=['python'], year=2019, views=77)
# 7500 Row(tags=['python'], year=2019, views=26)
# 7501 Row(tags=['python'], year=2019, views=200)
# 7502 Row(tags=['javascript'], year=2019, views=32)
# 7503 Row(tags=['python'], year=2019, views=230)
# 7504 Row(tags=['java'], year=2019, views=26)
# 7505 Row(tags=['javascript'], year=2019, views=32)
# 7506 Row(tags=['java'], year=2019, views=25)
# 7507 Row(tags=['python'], year=2019, views=445)
# 7508 Row(tags=['r'], year=2019, views=29)
# 7509 Row(tags=['javascript', 'dart'], year=2019, views=256)
# 7510 Row(tags=['scala'], year=2019, views=87)
# 7511 Row(tags=['php'], year=2019, views=135)
# 7512 Row(tags=['php'], year=2019, views=26)
# 7513 Row(tags=['java'], year=2019, views=92)
# 7514 Row(tags=['javascript', 'python'], year=2019, views=44)
# 7515 Row(tags=['scala'], year=2019, views=37)
# 7516 Row(tags=['python'], year=2019, views=310)
# 7517 Row(tags=['kotlin'], year=2019, views=74)
# 7518 Row(tags=['python'], year=2019, views=22)
# 7519 Row(tags=['python'], year=2019, views=29)
# 7520 Row(tags=['go'], year=2019, views=54)
# 7521 Row(tags=['python'], year=2019, views=153)
# 7522 Row(tags=['rust'], year=2019, views=79)
# 7523 Row(tags=['php'], year=2019, views=118)
# 7524 Row(tags=['python'], year=2017, views=853)
# 7525 Row(tags=['python'], year=2017, views=1376)
# 7526 Row(tags=['matlab'], year=2017, views=111)
# 7527 Row(tags=['r'], year=2017, views=20)
# 7528 Row(tags=['r'], year=2017, views=161)
# 7529 Row(tags=['awk'], year=2017, views=162)
# 7530 Row(tags=['python'], year=2017, views=392)
# 7531 Row(tags=['javascript'], year=2019, views=3370)
# 7532 Row(tags=['python'], year=2017, views=589)
# 7533 Row(tags=['java'], year=2017, views=266)
# 7534 Row(tags=['java'], year=2017, views=64)
# 7535 Row(tags=['javascript'], year=2017, views=44)
# 7536 Row(tags=['r'], year=2017, views=133)
# 7537 Row(tags=['r'], year=2017, views=556)
# 7538 Row(tags=['java'], year=2017, views=188)
# 7539 Row(tags=['java'], year=2019, views=997)
# 7540 Row(tags=['javascript'], year=2019, views=3845)
# 7541 Row(tags=['javascript'], year=2017, views=341)
# 7542 Row(tags=['javascript'], year=2017, views=455)
# 7543 Row(tags=['python'], year=2017, views=111)
# 7544 Row(tags=['objective-c'], year=2017, views=89)
# 7545 Row(tags=['python'], year=2017, views=42)
# 7546 Row(tags=['go'], year=2017, views=103)
# 7547 Row(tags=['python'], year=2017, views=238)
# 7548 Row(tags=['r'], year=2017, views=495)
# 7549 Row(tags=['java'], year=2017, views=16)
# 7550 Row(tags=['python'], year=2017, views=294)
# 7551 Row(tags=['java'], year=2017, views=65)
# 7552 Row(tags=['javascript'], year=2017, views=53)
# 7553 Row(tags=['javascript'], year=2017, views=66)
# 7554 Row(tags=['javascript'], year=2017, views=685)
# 7555 Row(tags=['haskell'], year=2017, views=1296)
# 7556 Row(tags=['typescript'], year=2017, views=1002)
# 7557 Row(tags=['r'], year=2019, views=2504)
# 7558 Row(tags=['javascript'], year=2017, views=58)
# 7559 Row(tags=['java'], year=2017, views=80)
# 7560 Row(tags=['javascript', 'io'], year=2017, views=58)
# 7561 Row(tags=['python'], year=2017, views=283)
# 7562 Row(tags=['javascript'], year=2017, views=33)
# 7563 Row(tags=['objective-c'], year=2017, views=270)
# 7564 Row(tags=['javascript'], year=2017, views=34)
# 7565 Row(tags=['php'], year=2017, views=77)
# 7566 Row(tags=['objective-c'], year=2018, views=71)
# 7567 Row(tags=['php'], year=2018, views=25)
# 7568 Row(tags=['r'], year=2018, views=48)
# 7569 Row(tags=['php'], year=2018, views=124)
# 7570 Row(tags=['c'], year=2018, views=86)
# 7571 Row(tags=['powershell'], year=2018, views=42)
# 7572 Row(tags=['r'], year=2018, views=70)
# 7573 Row(tags=['java'], year=2018, views=37)
# 7574 Row(tags=['python'], year=2019, views=18545)
# 7575 Row(tags=['php'], year=2018, views=56)
# 7576 Row(tags=['python'], year=2018, views=48)
# 7577 Row(tags=['python'], year=2018, views=24)
# 7578 Row(tags=['php'], year=2018, views=28)
# 7579 Row(tags=['java'], year=2019, views=76)
# 7580 Row(tags=['php'], year=2018, views=124)
# 7581 Row(tags=['javascript'], year=2019, views=57)
# 7582 Row(tags=['java'], year=2011, views=237)
# 7583 Row(tags=['ruby'], year=2012, views=2395)
# 7584 Row(tags=['objective-c'], year=2011, views=1229)
# 7585 Row(tags=['php'], year=2011, views=1439)
# 7586 Row(tags=['php'], year=2011, views=804)
# 7587 Row(tags=['coldfusion'], year=2011, views=139)
# 7588 Row(tags=['javascript'], year=2011, views=186)
# 7589 Row(tags=['php'], year=2012, views=399)
# 7590 Row(tags=['php'], year=2011, views=5821)
# 7591 Row(tags=['php', 'dbase'], year=2011, views=1064)
# 7592 Row(tags=['php'], year=2011, views=3491)
# 7593 Row(tags=['xpath'], year=2011, views=553)
# 7594 Row(tags=['javascript'], year=2011, views=3905)
# 7595 Row(tags=['java'], year=2011, views=2170)
# 7596 Row(tags=['java'], year=2011, views=38)
# 7597 Row(tags=['python', 'ruby'], year=2018, views=638)
# 7598 Row(tags=['php', 'javascript'], year=2011, views=165)
# 7599 Row(tags=['python'], year=2017, views=14771)
# 7600 Row(tags=['ruby'], year=2011, views=237)
# 7601 Row(tags=['php'], year=2011, views=1023)
# 7602 Row(tags=['java'], year=2014, views=24861)
# 7603 Row(tags=['php'], year=2011, views=4084)
# 7604 Row(tags=['javascript'], year=2011, views=4596)
# 7605 Row(tags=['javascript'], year=2011, views=494)
# 7606 Row(tags=['php'], year=2011, views=74)
# 7607 Row(tags=['glsl'], year=2012, views=1950)
# 7608 Row(tags=['php'], year=2012, views=1189)
# 7609 Row(tags=['php', 'javascript'], year=2012, views=236)
# 7610 Row(tags=['php'], year=2012, views=119)
# 7611 Row(tags=['java'], year=2012, views=45)
# 7612 Row(tags=['javascript'], year=2015, views=12857)
# 7613 Row(tags=['javascript'], year=2016, views=13240)
# 7614 Row(tags=['ruby'], year=2012, views=564)
# 7615 Row(tags=['javascript'], year=2012, views=169)
# 7616 Row(tags=['objective-c'], year=2012, views=244)
# 7617 Row(tags=['python'], year=2012, views=158)
# 7618 Row(tags=['java'], year=2012, views=156)
# 7619 Row(tags=['javascript'], year=2012, views=4182)
# 7620 Row(tags=['javascript'], year=2012, views=303)
# 7621 Row(tags=['java'], year=2012, views=21235)
# 7622 Row(tags=['php'], year=2012, views=245)
# 7623 Row(tags=['java'], year=2012, views=65)
# 7624 Row(tags=['matlab'], year=2012, views=73)
# 7625 Row(tags=['java'], year=2012, views=306)
# 7626 Row(tags=['c'], year=2012, views=62)
# 7627 Row(tags=['java'], year=2012, views=2394)
# 7628 Row(tags=['java'], year=2012, views=539)
# 7629 Row(tags=['php', 'curl'], year=2012, views=1518)
# 7630 Row(tags=['powershell'], year=2013, views=3600)
# 7631 Row(tags=['php'], year=2012, views=56)
# 7632 Row(tags=['objective-c'], year=2012, views=63)
# 7633 Row(tags=['r'], year=2013, views=3302)
# 7634 Row(tags=['php'], year=2012, views=136)
# 7635 Row(tags=['php'], year=2015, views=20919)
# 7636 Row(tags=['lua'], year=2012, views=10691)
# 7637 Row(tags=['javascript'], year=2012, views=1551)
# 7638 Row(tags=['java'], year=2016, views=10262)
# 7639 Row(tags=['php'], year=2012, views=2923)
# 7640 Row(tags=['php'], year=2012, views=2222)
# 7641 Row(tags=['objective-c'], year=2014, views=38)
# 7642 Row(tags=['r'], year=2014, views=3375)
# 7643 Row(tags=['haskell'], year=2017, views=1376)
# 7644 Row(tags=['c'], year=2015, views=2643)
# 7645 Row(tags=['python'], year=2016, views=2280)
# 7646 Row(tags=['java'], year=2014, views=1232)
# 7647 Row(tags=['java'], year=2014, views=347)
# 7648 Row(tags=['objective-c'], year=2014, views=424)
# 7649 Row(tags=['java'], year=2014, views=1872)
# 7650 Row(tags=['python', 'matlab'], year=2014, views=2229)
# 7651 Row(tags=['java'], year=2014, views=579)
# 7652 Row(tags=['javascript'], year=2014, views=1163)
# 7653 Row(tags=['java'], year=2014, views=868)
# 7654 Row(tags=['java'], year=2014, views=380)
# 7655 Row(tags=['python'], year=2014, views=53)
# 7656 Row(tags=['javascript'], year=2014, views=59)
# 7657 Row(tags=['javascript'], year=2014, views=240)
# 7658 Row(tags=['python'], year=2018, views=157)
# 7659 Row(tags=['javascript'], year=2014, views=57)
# 7660 Row(tags=['java'], year=2014, views=1070)
# 7661 Row(tags=['c'], year=2014, views=799)
# 7662 Row(tags=['javascript'], year=2014, views=41)
# 7663 Row(tags=['curl'], year=2014, views=677)
# 7664 Row(tags=['javascript'], year=2014, views=88)
# 7665 Row(tags=['bash'], year=2014, views=411)
# 7666 Row(tags=['python'], year=2014, views=298)
# 7667 Row(tags=['java'], year=2014, views=736)
# 7668 Row(tags=['java'], year=2015, views=1146)
# 7669 Row(tags=['javascript', 'php'], year=2014, views=63)
# 7670 Row(tags=['php'], year=2014, views=68)
# 7671 Row(tags=['javascript'], year=2017, views=46)
# 7672 Row(tags=['java'], year=2014, views=1087)
# 7673 Row(tags=['javascript'], year=2014, views=226)
# 7674 Row(tags=['objective-c'], year=2014, views=103)
# 7675 Row(tags=['java', 'mouse'], year=2014, views=2500)
# 7676 Row(tags=['cuda'], year=2014, views=1627)
# 7677 Row(tags=['java'], year=2015, views=240)
# 7678 Row(tags=['objective-c'], year=2014, views=79)
# 7679 Row(tags=['java'], year=2014, views=1762)
# 7680 Row(tags=['java'], year=2014, views=57)
# 7681 Row(tags=['java'], year=2014, views=2300)
# 7682 Row(tags=['php'], year=2015, views=158)
# 7683 Row(tags=['java'], year=2014, views=2253)
# 7684 Row(tags=['c'], year=2018, views=168)
# 7685 Row(tags=['java'], year=2014, views=34)
# 7686 Row(tags=['javascript'], year=2015, views=57)
# 7687 Row(tags=['php'], year=2014, views=690)
# 7688 Row(tags=['java'], year=2014, views=91)
# 7689 Row(tags=['java'], year=2014, views=283)
# 7690 Row(tags=['java'], year=2014, views=2983)
# 7691 Row(tags=['php'], year=2014, views=39)
# 7692 Row(tags=['javascript'], year=2014, views=107)
# 7693 Row(tags=['javascript'], year=2014, views=253)
# 7694 Row(tags=['php'], year=2014, views=241)
# 7695 Row(tags=['python'], year=2016, views=95)
# 7696 Row(tags=['php'], year=2019, views=2345)
# 7697 Row(tags=['java'], year=2017, views=332)
# 7698 Row(tags=['powershell'], year=2016, views=50)
# 7699 Row(tags=['applescript'], year=2016, views=287)
# 7700 Row(tags=['javascript'], year=2016, views=69)
# 7701 Row(tags=['python'], year=2016, views=217)
# 7702 Row(tags=['matlab'], year=2016, views=135)
# 7703 Row(tags=['java'], year=2016, views=288)
# 7704 Row(tags=['javascript'], year=2016, views=758)
# 7705 Row(tags=['javascript'], year=2016, views=618)
# 7706 Row(tags=['c', 'r'], year=2016, views=376)
# 7707 Row(tags=['objective-c'], year=2016, views=128)
# 7708 Row(tags=['javascript'], year=2016, views=1800)
# 7709 Row(tags=['ruby'], year=2016, views=147)
# 7710 Row(tags=['javascript'], year=2016, views=46)
# 7711 Row(tags=['javascript'], year=2016, views=288)
# 7712 Row(tags=['java'], year=2016, views=1320)
# 7713 Row(tags=['php'], year=2016, views=30)
# 7714 Row(tags=['go'], year=2016, views=65)
# 7715 Row(tags=['javascript'], year=2019, views=64978)
# 7716 Row(tags=['sas'], year=2016, views=873)
# 7717 Row(tags=['java'], year=2016, views=71)
# 7718 Row(tags=['php'], year=2016, views=494)
# 7719 Row(tags=['php'], year=2016, views=467)
# 7720 Row(tags=['java'], year=2016, views=505)
# 7721 Row(tags=['javascript'], year=2016, views=107)
# 7722 Row(tags=['javascript'], year=2016, views=57)
# 7723 Row(tags=['octave'], year=2017, views=1512)
# 7724 Row(tags=['javascript'], year=2017, views=757)
# 7725 Row(tags=['php'], year=2017, views=82)
# 7726 Row(tags=['php'], year=2017, views=270)
# 7727 Row(tags=['c'], year=2017, views=122)
# 7728 Row(tags=['java', 'scala'], year=2017, views=378)
# 7729 Row(tags=['php'], year=2017, views=58)
# 7730 Row(tags=['java'], year=2017, views=197)
# 7731 Row(tags=['java'], year=2017, views=1491)
# 7732 Row(tags=['python'], year=2017, views=49)
# 7733 Row(tags=['javascript', 'php'], year=2017, views=54)
# 7734 Row(tags=['php'], year=2017, views=1249)
# 7735 Row(tags=['php'], year=2017, views=229)
# 7736 Row(tags=['javascript'], year=2017, views=846)
# 7737 Row(tags=['javascript'], year=2017, views=44)
# 7738 Row(tags=['javascript'], year=2017, views=52)
# 7739 Row(tags=['php'], year=2017, views=5019)
# 7740 Row(tags=['java', 'python'], year=2017, views=459)
# 7741 Row(tags=['java'], year=2017, views=203)
# 7742 Row(tags=['javascript'], year=2017, views=48)
# 7743 Row(tags=['javascript'], year=2017, views=62)
# 7744 Row(tags=['php'], year=2017, views=35)
# 7745 Row(tags=['python'], year=2018, views=1269)
# 7746 Row(tags=['python'], year=2018, views=168)
# 7747 Row(tags=['python'], year=2018, views=993)
# 7748 Row(tags=['c'], year=2018, views=184)
# 7749 Row(tags=['java'], year=2018, views=301)
# 7750 Row(tags=['java'], year=2018, views=342)
# 7751 Row(tags=['java'], year=2018, views=714)
# 7752 Row(tags=['javascript'], year=2018, views=59)
# 7753 Row(tags=['r'], year=2018, views=861)
# 7754 Row(tags=['javascript', 'typescript'], year=2018, views=62)
# 7755 Row(tags=['javascript'], year=2018, views=837)
# 7756 Row(tags=['scala'], year=2018, views=182)
# 7757 Row(tags=['java'], year=2018, views=574)
# 7758 Row(tags=['r'], year=2018, views=139)
# 7759 Row(tags=['php'], year=2018, views=53)
# 7760 Row(tags=['r'], year=2018, views=142)
# 7761 Row(tags=['python'], year=2018, views=4462)
# 7762 Row(tags=['python'], year=2018, views=82)
# 7763 Row(tags=['javascript'], year=2018, views=51)
# 7764 Row(tags=['java'], year=2018, views=30)
# 7765 Row(tags=['python'], year=2018, views=32)
# 7766 Row(tags=['python'], year=2018, views=46)
# 7767 Row(tags=['javascript'], year=2018, views=233)
# 7768 Row(tags=['bash'], year=2018, views=160)
# 7769 Row(tags=['java'], year=2018, views=317)
# 7770 Row(tags=['r'], year=2018, views=111)
# 7771 Row(tags=['delphi'], year=2018, views=231)
# 7772 Row(tags=['javascript', 'python'], year=2018, views=1293)
# 7773 Row(tags=['python'], year=2019, views=9235)
# 7774 Row(tags=['powershell'], year=2018, views=166)
# 7775 Row(tags=['python'], year=2018, views=82)
# 7776 Row(tags=['java'], year=2018, views=543)
# 7777 Row(tags=['java'], year=2018, views=581)
# 7778 Row(tags=['java'], year=2018, views=936)
# 7779 Row(tags=['java'], year=2018, views=587)
# 7780 Row(tags=['python'], year=2018, views=90)
# 7781 Row(tags=['curl'], year=2018, views=755)
# 7782 Row(tags=['objective-c'], year=2018, views=39)
# 7783 Row(tags=['labview'], year=2019, views=55)
# 7784 Row(tags=['python'], year=2019, views=58)
# 7785 Row(tags=['r'], year=2019, views=27)
# 7786 Row(tags=['perl'], year=2019, views=23)
# 7787 Row(tags=['python', 'go'], year=2019, views=48)
# 7788 Row(tags=['c'], year=2019, views=81)
# 7789 Row(tags=['r'], year=2019, views=37)
# 7790 Row(tags=['php'], year=2019, views=32)
# 7791 Row(tags=['python'], year=2019, views=25)
# 7792 Row(tags=['java'], year=2019, views=43)
# 7793 Row(tags=['kotlin'], year=2019, views=23)
# 7794 Row(tags=['javascript'], year=2019, views=32)
# 7795 Row(tags=['python'], year=2019, views=43)
# 7796 Row(tags=['javascript'], year=2019, views=17)
# 7797 Row(tags=['php'], year=2019, views=30)
# 7798 Row(tags=['javascript'], year=2019, views=35)
# 7799 Row(tags=['javascript'], year=2019, views=42)
# 7800 Row(tags=['python'], year=2019, views=35)
# 7801 Row(tags=['javascript'], year=2019, views=45)
# 7802 Row(tags=['dart'], year=2019, views=93)
# 7803 Row(tags=['python'], year=2019, views=31)
# 7804 Row(tags=['javascript'], year=2019, views=42)
# 7805 Row(tags=['javascript'], year=2019, views=19)
# 7806 Row(tags=['r'], year=2019, views=15)
# 7807 Row(tags=['python', 'tpu'], year=2019, views=104)
# 7808 Row(tags=['bash'], year=2019, views=18)
# 7809 Row(tags=['python'], year=2019, views=29)
# 7810 Row(tags=['python'], year=2019, views=42)
# 7811 Row(tags=['javascript'], year=2019, views=47)
# 7812 Row(tags=['kotlin'], year=2019, views=30)
# 7813 Row(tags=['python'], year=2019, views=32)
# 7814 Row(tags=['java'], year=2019, views=18)
# 7815 Row(tags=['php'], year=2019, views=31)
# 7816 Row(tags=['javascript'], year=2019, views=29)
# 7817 Row(tags=['f#'], year=2019, views=56)
# 7818 Row(tags=['r'], year=2019, views=3)

# %%
results = {}

for i in range(2010, 2021):
    posts_data_sorted = posts_data_simplified \
    .select("year", explode("tags").alias("tag"), "views") \
    .filter(f"year = {i}") \
    .groupBy("year", "tag") \
    .agg(sum("views").alias("total_views")) \
    .orderBy(col('total_views').desc())
    results[i] = posts_data_sorted

# %%
for year in results.keys():
    results[year].write.format("parquet").save(f"top_{year}")

# %%
print(results[2010])
print(results[2019])
# Out:
# +----+------------+-----------+
# |year|         tag|total_views|
# +----+------------+-----------+
# |2010|        java|      53333|
# |2010|      matlab|      51865|
# |2010| objective-c|      43878|
# |2010|         php|      39730|
# |2010|  javascript|      37059|
# |2010|      python|      25930|
# |2010|        ruby|      15864|
# |2010|           c|      13810|
# |2010|      delphi|       7680|
# |2010|           r|       7499|
# |2010|       xpath|       5122|
# |2010|actionscript|       5104|
# |2010|         sed|       4573|
# |2010|        perl|       3515|
# |2010|     haskell|       2601|
# |2010|        bash|       2171|
# |2010|       mouse|       1789|
# |2010|      racket|       1539|
# |2010|      scheme|       1539|
# |2010| applescript|       1462|
# +----+------------+-----------+
# only showing top 20 rows
#
# +----+-----------+-----------+
# |year|        tag|total_views|
# +----+-----------+-----------+
# |2019|     python|    3408726|
# |2019|        php|    1513426|
# |2019| javascript|     877473|
# |2019|       java|     570380|
# |2019|objective-c|     430671|
# |2019|          r|      51923|
# |2019|       ruby|      44877|
# |2019|         io|      43094|
# |2019|       bash|      23877|
# |2019| typescript|      18984|
# |2019| powershell|      15202|
# |2019|     scheme|      13014|
# |2019|          c|      11940|
# |2019|         go|      10771|
# |2019|    haskell|      10658|
# |2019|       dart|      10618|
# |2019|     kotlin|       9495|
# |2019|       rust|       5589|
# |2019|      scala|       4553|
# |2019|       abap|       2774|
# +----+-----------+-----------+
# only showing top 20 rows
